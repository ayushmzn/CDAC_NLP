# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
para = """Every part of an essay is important, but the first paragraph is vital.
This is the first chance you have to impress – or depress – an examiner, and first impressions are often decisive.
You might therefore try to write an eye-catching first sentence.
(‘Start with an earthquake and work up to a climax,’ counselled the film-maker Cecil B. De Mille.)
More important is that you demonstrate your understanding of the question set. 
Here you give your carefully thought out definitions of the key terms, 
and here you establish the relevant time-frame and issues – in other words, 
the parameters of the question. Also, you divide the overall question into more manageable sub-divisions,
or smaller questions, on each of which you will subsequently write a paragraph. 
You formulate an argument, or perhaps voice alternative lines of argument, 
that you will substantiate later in the essay. Hence the first paragraph – 
or perhaps you might spread this opening section over two paragraphs – is the key to a good essay."""

# %%
sentences_in_paragraph = nltk.sent_tokenize(para)
flag=0
for i in sentences_in_paragraph:
    print(flag, '-',i)
    flag+=1
# Out:
# 0 - Every part of an essay is important, but the first paragraph is vital.
# 1 - This is the first chance you have to impress – or depress – an examiner, and first impressions are often decisive.
# 2 - You might therefore try to write an eye-catching first sentence.
# 3 - (‘Start with an earthquake and work up to a climax,’ counselled the film-maker Cecil B.
# 4 - De Mille.)
# 5 - More important is that you demonstrate your understanding of the question set.
# 6 - Here you give your carefully thought out definitions of the key terms,
# and here you establish the relevant time-frame and issues – in other words,
# the parameters of the question.
# 7 - Also, you divide the overall question into more manageable sub-divisions,
# or smaller questions, on each of which you will subsequently write a paragraph.
# 8 - You formulate an argument, or perhaps voice alternative lines of argument,
# that you will substantiate later in the essay.
# 9 - Hence the first paragraph –
# or perhaps you might spread this opening section over two paragraphs – is the key to a good essay.

# %%
words_in_paragraph = nltk.word_tokenize(para)
flag=1
for i in words_in_paragraph:
    print(flag, '-',i)
    flag+=1
# Out:
# 1 - Every
# 2 - part
# 3 - of
# 4 - an
# 5 - essay
# 6 - is
# 7 - important
# 8 - ,
# 9 - but
# 10 - the
# 11 - first
# 12 - paragraph
# 13 - is
# 14 - vital
# 15 - .
# 16 - This
# 17 - is
# 18 - the
# 19 - first
# 20 - chance
# 21 - you
# 22 - have
# 23 - to
# 24 - impress
# 25 - –
# 26 - or
# 27 - depress
# 28 - –
# 29 - an
# 30 - examiner
# 31 - ,
# 32 - and
# 33 - first
# 34 - impressions
# 35 - are
# 36 - often
# 37 - decisive
# 38 - .
# 39 - You
# 40 - might
# 41 - therefore
# 42 - try
# 43 - to
# 44 - write
# 45 - an
# 46 - eye-catching
# 47 - first
# 48 - sentence
# 49 - .
# 50 - (
# 51 - ‘
# 52 - Start
# 53 - with
# 54 - an
# 55 - earthquake
# 56 - and
# 57 - work
# 58 - up
# 59 - to
# 60 - a
# 61 - climax
# 62 - ,
# 63 - ’
# 64 - counselled
# 65 - the
# 66 - film-maker
# 67 - Cecil
# 68 - B
# 69 - .
# 70 - De
# 71 - Mille
# 72 - .
# 73 - )
# 74 - More
# 75 - important
# 76 - is
# 77 - that
# 78 - you
# 79 - demonstrate
# 80 - your
# 81 - understanding
# 82 - of
# 83 - the
# 84 - question
# 85 - set
# 86 - .
# 87 - Here
# 88 - you
# 89 - give
# 90 - your
# 91 - carefully
# 92 - thought
# 93 - out
# 94 - definitions
# 95 - of
# 96 - the
# 97 - key
# 98 - terms
# 99 - ,
# 100 - and
# 101 - here
# 102 - you
# 103 - establish
# 104 - the
# 105 - relevant
# 106 - time-frame
# 107 - and
# 108 - issues
# 109 - –
# 110 - in
# 111 - other
# 112 - words
# 113 - ,
# 114 - the
# 115 - parameters
# 116 - of
# 117 - the
# 118 - question
# 119 - .
# 120 - Also
# 121 - ,
# 122 - you
# 123 - divide
# 124 - the
# 125 - overall
# 126 - question
# 127 - into
# 128 - more
# 129 - manageable
# 130 - sub-divisions
# 131 - ,
# 132 - or
# 133 - smaller
# 134 - questions
# 135 - ,
# 136 - on
# 137 - each
# 138 - of
# 139 - which
# 140 - you
# 141 - will
# 142 - subsequently
# 143 - write
# 144 - a
# 145 - paragraph
# 146 - .
# 147 - You
# 148 - formulate
# 149 - an
# 150 - argument
# 151 - ,
# 152 - or
# 153 - perhaps
# 154 - voice
# 155 - alternative
# 156 - lines
# 157 - of
# 158 - argument
# 159 - ,
# 160 - that
# 161 - you
# 162 - will
# 163 - substantiate
# 164 - later
# 165 - in
# 166 - the
# 167 - essay
# 168 - .
# 169 - Hence
# 170 - the
# 171 - first
# 172 - paragraph
# 173 - –
# 174 - or
# 175 - perhaps
# 176 - you
# 177 - might
# 178 - spread
# 179 - this
# 180 - opening
# 181 - section
# 182 - over
# 183 - two
# 184 - paragraphs
# 185 - –
# 186 - is
# 187 - the
# 188 - key
# 189 - to
# 190 - a
# 191 - good
# 192 - essay
# 193 - .
